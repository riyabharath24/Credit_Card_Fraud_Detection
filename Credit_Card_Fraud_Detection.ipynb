# %%
import pandas as pd

credit_data = pd.read_csv('creditcard.csv')
credit_data
# Out:
#         Time        V1        V2        V3        V4        V5        V6  \
# 0          0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388
# 1          0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361
# 2          1 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499
# 3          1 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203
# 4          2 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921
# ...      ...       ...       ...       ...       ...       ...       ...
# 13949  24754  1.252924 -0.182189 -0.802716 -0.210981  1.916713  3.643624
# 13950  24756 -0.346979 -2.103284 -0.685061  1.961605 -0.401125  0.473632
# 13951  24759 -6.053652 -5.988723  0.810413 -0.011811  1.308135 -0.590803
# 13952  24759  1.169121 -1.284945  0.032717 -0.681670  0.660598  4.412578
# 13953  24759 -6.917152  5.854171 -1.652458 -1.488884 -0.833891 -0.344418
#
#              V7        V8        V9  ...       V21       V22       V23  \
# ...

# %%
credit_data.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0     0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1     0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2     1 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3     1 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4     2 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %%
credit_data.tail()
# Out:
#         Time        V1        V2        V3        V4        V5        V6  \
# 13949  24754  1.252924 -0.182189 -0.802716 -0.210981  1.916713  3.643624
# 13950  24756 -0.346979 -2.103284 -0.685061  1.961605 -0.401125  0.473632
# 13951  24759 -6.053652 -5.988723  0.810413 -0.011811  1.308135 -0.590803
# 13952  24759  1.169121 -1.284945  0.032717 -0.681670  0.660598  4.412578
# 13953  24759 -6.917152  5.854171 -1.652458 -1.488884 -0.833891 -0.344418
#
#              V7        V8        V9  ...       V21       V22       V23  \
# 13949 -0.778711  0.818295  1.706962  ... -0.497088 -1.211285  0.043809
# 13950  1.133816 -0.256528  0.893409  ...  0.359662 -0.316275 -0.864259
# 13951 -0.725838 -0.234840  1.624646  ... -0.771970  1.474668  3.176363
# 13952 -1.913115  1.076592  1.501230  ... -0.557596 -0.882435 -0.041523
# 13953  0.393789  0.379968  6.133597  ... -1.404681 -1.124694  0.174333
#
#             V24       V25       V26       V27       V28  Amount  Class
# ...

# %%
credit_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13954 entries, 0 to 13953
# Data columns (total 31 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Time    13954 non-null  int64
#  1   V1      13954 non-null  float64
#  2   V2      13954 non-null  float64
#  3   V3      13954 non-null  float64
#  4   V4      13954 non-null  float64
#  5   V5      13954 non-null  float64
#  6   V6      13954 non-null  float64
#  7   V7      13954 non-null  float64
#  8   V8      13954 non-null  float64
#  9   V9      13954 non-null  float64
#  10  V10     13954 non-null  float64
#  11  V11     13954 non-null  float64
#  12  V12     13954 non-null  float64
#  13  V13     13954 non-null  float64
#  14  V14     13954 non-null  float64
#  15  V15     13954 non-null  float64
#  16  V16     13954 non-null  float64
#  17  V17     13954 non-null  float64
#  18  V18     13954 non-null  float64
#  19  V19     13954 non-null  float64
# ...

# %%
credit_data.isnull().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       0
# V27       0
# V28       0
# Amount    1
# Class     1
# dtype: int64

# %%
credit_data = credit_data.dropna(axis=0)
credit_data.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0     0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1     0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2     1 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3     1 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4     2 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %%
print(f"Unique values of target variable :- \n {credit_data['Class'].unique()}")
# Out:
# Unique values of target variable :-
#  [0. 1.]

# %%
print(f"Number of samples under each target value :- \n {credit_data['Class'].value_counts()}")
# Out:
# Number of samples under each target value :-
#  0.0    13897
# 1.0       56
# Name: Class, dtype: int64

# %%
credit_data.hist(bins=30, figsize=(30, 30))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f7f70ee3ac0>,
# ...
#       dtype=object)

# %%
import matplotlib.pyplot as plt
import seaborn as sns

sns.heatmap(credit_data.corr(),cmap = 'coolwarm',cbar = True)

# %%
labels = credit_data.Class.unique()


# get the count of each class
sizes = credit_data.Class.value_counts().values

# plot the class value counts
fig, ax = plt.subplots()
ax.pie(sizes, labels=labels, autopct='%1.3f%%')
ax.set_title('Target Variable Value Counts')
plt.show()

# %%
fig, ax = plt.subplots(figsize=(12, 10))

# All transactions over time
sns.histplot(ax=ax, data=credit_data, x='Time',bins=48, kde=True, stat='density', kde_kws=dict(cut=3), color='orange')
ax.set_title('All Transactions over Time')
ax.set_xlim(min(credit_data['Time'].values), max(credit_data['Time'].values))
ax.set_xlabel('Seconds after the First Transaction')
# Out:
# Text(0.5, 0, 'Seconds after the First Transaction')

# %%
print(f"Unique values of target variable :- \n {credit_data['Class'].unique()}")
# Out:
# Unique values of target variable :-
#  [0. 1.]

# %%
print(f"Number of samples under each target value :- \n {credit_data['Class'].value_counts()}")
# Out:
# Number of samples under each target value :-
#  0.0    13897
# 1.0       56
# Name: Class, dtype: int64

# %%
credit_data = credit_data.drop(['Time'], axis=1)
print(f"list of feature names after removing Time column :- \n{credit_data.columns}")
# Out:
# list of feature names after removing Time column :-
# Index(['V1', 'V2', 'V3', 'V4', 'V5', 'V6', 'V7', 'V8', 'V9', 'V10', 'V11',
#        'V12', 'V13', 'V14', 'V15', 'V16', 'V17', 'V18', 'V19', 'V20', 'V21',
#        'V22', 'V23', 'V24', 'V25', 'V26', 'V27', 'V28', 'Amount', 'Class'],
#       dtype='object')

# %%
#data transformation
print(f"few values of Amount column :- \n {credit_data['Amount'][0:4]}")
# Out:
# few values of Amount column :-
#  0    149.62
# 1      2.69
# 2    378.66
# 3    123.50
# Name: Amount, dtype: float64

# %% [markdown]
#  **Data Preprocessing**

# %%
from sklearn.preprocessing import StandardScaler
credit_data['norm_amount'] = StandardScaler().fit_transform(credit_data['Amount'].values.reshape(-1,1))
credit_data = credit_data.drop(['Amount'], axis=1)
print(f"few values of Amount column after applying StandardScaler:- \n {credit_data['norm_amount'][0:4]}")
# Out:
# few values of Amount column after applying StandardScaler:-
#  0    0.481995
# 1   -0.344008
# 2    1.769600
# 3    0.335155
# Name: norm_amount, dtype: float64

# %%
X = credit_data.drop(['Class'], axis =1)
y = credit_data[['Class']]

# %%
#forming the train and test datasets
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=0)
print(X_train.shape)
print(X_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (9767, 29)
# (4186, 29)
# (9767, 1)
# (4186, 1)

# %%
# Building a decision tree
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report

def decision_tree_classification(X_train, y_train, X_test, y_test):
  # initialize object
  dt_classifier = DecisionTreeClassifier()
  # train model
  dt_classifier.fit(X_train, y_train.values.ravel())
  acc_score = dt_classifier.score(X_test, y_test)
  print(f'Accuracy of model on test dataset :- {acc_score}')
  # predict result using test dataset
  y_pred = dt_classifier.predict(X_test)
  # confusion matrix
  print(f"Confusion Matrix :- \n {confusion_matrix(y_test, y_pred)}")
  # classification report for f1-score
  print(f"Classification Report :- \n {classification_report(y_test, y_pred)}")

#calling decision_tree_classification method to train and evaluate model
decision_tree_classification(X_train, y_train, X_test, y_test)
# Out:
# Accuracy of model on test dataset :- 0.9988055422838031
# Confusion Matrix :-
#  [[4168    4]
#  [   1   13]]
# Classification Report :-
#                precision    recall  f1-score   support
#
#          0.0       1.00      1.00      1.00      4172
#          1.0       0.76      0.93      0.84        14
#
#     accuracy                           1.00      4186
#    macro avg       0.88      0.96      0.92      4186
# weighted avg       1.00      1.00      1.00      4186

# %%
## Target Class Distribution
class_val = credit_data['Class'].value_counts()
print(f"Number of samples for each class :- \n {class_val}")
non_fraud = class_val[0]
fraud = class_val[1]
print(f"Non Fraudulent Numbers :- {non_fraud}")
print(f"Fraudulent Numbers :- {fraud}")
# Out:
# Number of samples for each class :-
#  0.0    13897
# 1.0       56
# Name: Class, dtype: int64
# Non Fraudulent Numbers :- 13897
# Fraudulent Numbers :- 56

# %%
import numpy as np
nonfraud_indexies = credit_data[credit_data.Class == 0].index
fraud_indices = np.array(credit_data[credit_data['Class'] == 1].index)
# take random samples from non fraudulent that are equal to fraudulent samples
random_normal_indexies = np.random.choice(nonfraud_indexies, fraud, replace=False)
random_normal_indexies = np.array(random_normal_indexies)


## Undersampling techniques

# concatenate both indices of fraud and non fraud
under_sample_indices = np.concatenate([fraud_indices, random_normal_indexies])

#extract all features from whole data for under sample indices only
under_sample_data = credit_data.iloc[under_sample_indices, :]

# now we have to divide under sampling data to all features & target
x_undersample_data = under_sample_data.drop(['Class'], axis=1)
y_undersample_data = under_sample_data[['Class']]
# now split dataset to train and test datasets as before
X_train_sample, X_test_sample, y_train_sample, y_test_sample = train_test_split(
x_undersample_data, y_undersample_data, test_size=0.2, random_state=0)

# %%
## DecisionTreeClassifier after applying undersampling technique

from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report
from sklearn.metrics import roc_auc_score

def decision_tree_classification(X_train, y_train, X_test, y_test):
 # initialize object for DecisionTreeClassifier class
 dt_classifier = DecisionTreeClassifier()
 # train model by using fit method
 dt_classifier.fit(X_train, y_train.values.ravel())
 acc_score = dt_classifier.score(X_test, y_test)
 print(f'Accuracy of model on test dataset :- {acc_score}')
 # predict result using test dataset
 y_pred = dt_classifier.predict(X_test)
 # confusion matrix
 print(f"Confusion Matrix :- \n {confusion_matrix(y_test, y_pred)}")
 # classification report for f1-score
 print(f"Classification Report :- \n {classification_report(y_test, y_pred)}")
 print(f"AROC score :- \n {roc_auc_score(y_test, y_pred)}")

# calling decision tree classifier function 
decision_tree_classification(X_train_sample, y_train_sample, 
X_test_sample, y_test_sample)
# Out:
# Accuracy of model on test dataset :- 0.9565217391304348
# Confusion Matrix :-
#  [[11  1]
#  [ 0 11]]
# Classification Report :-
#                precision    recall  f1-score   support
#
#          0.0       1.00      0.92      0.96        12
#          1.0       0.92      1.00      0.96        11
#
#     accuracy                           0.96        23
#    macro avg       0.96      0.96      0.96        23
# weighted avg       0.96      0.96      0.96        23
#
# AROC score :-
#  0.9583333333333333
